# %% [markdown]
# 1) Datatypes are values which can be held by a variable.
# Numeric:
# int: represents integer values (ex: 0, 1, 2, ...)
# float: represents floating point values (ex: 0.5, 3.1425, ...)
# complex: represents complex numbers (ex: 3 + 5j)
#
# Sequence data:
# str: represents string (ex: "hello world")
# list: represents an ordered collection of elements (ex: [1, 2, 3], ['a', 'b'])
# tuples: represents immutable collection of ordered elements (ex: (1, 2, 3))
# dict: represents a sequence of key-pair value {'key':'value', 'age':21}

# %% [markdown]
# 2) list: List is an ordered collection of elements which is mutable. List elements maintain their order in which they are inserted into the list which allows
# duplicate elements to be inserted.
#
# tuple: Tuples are ordered collection of elements which is immutable. The list can contain duplicate elements and each element can be accessed using indices.
#
# set: Set does not have any specific order where the elements can be added or deleted after creation. It cannot contain duplicate entries.
#
# 3) Python allows handeling errors and exceptions using python's exception handeling tools such as 'try', 'catch' and 'finally'.
#
# try: The code that may potentially raise an exception is enclosed within try block. If an exception is encountered, the execution is immediatly jumps to an appropriate catch block.
#
# except: except generally follows try block and contains code which handels specific exceptions which are raised in try block. Multiple catch blocks may exist to handle various exceptions.
#
# finally: it is an optional block which follows try and except blocks. This block is always executed, regardless of whether an exception is raised or not.

# %% [markdown]
# 4) Decorators are tools used in python to modify the behaviour of a function or
# class without directly altering the source code. This provides a way to add new
# or additional features to existing code in a modular way.

# %%
# example
def my_decorator(func):
    def wrapper(*args, **kwargs):
        print("Before function call")
        result = func(*args, **kwargs)
        print("After function call")
        return result
    return wrapper

@my_decorator
def greet(name):
    print("Hello,", name)

greet("Alice")

# %% [markdown]
# 5) Lambda function or anonymous function is a small defined funciton which is not explicitly named by the programmer. It is typically used for short and one-line expressions.

# %%
square = lambda x: x * x
res = square(5)
print(res)

# %% [markdown]
# 6) Python provides various file handeling features which enable various file level operations like opening a file, reading it's contents, and writing to it.

# %%
# example
with open('example.txt', 'r') as file:
    content = file.read()
    print(content)

# %% [markdown]
# 7) Encapsulaiton: Refers to bundeling of data and methods which operate as a single entity or unit. The internal implementation details are hidden from the user.

# %%
class Person:
    def __init__(self, name, age):
      self.__name = name
      self.__age = age

    def get_name(self):
        return self.__name

    def get_age(self):
        return self.__age

# %% [markdown]
# Abstraction: It simplifies a complex system by focusing on more essential features.

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def make_sound(self):
        pass  # Abstract method

class Dog(Animal):
    def make_sound(self):

        print("Woof!")

class Cat(Animal):
    def make_sound(self):
        print("Meow!")

# %% [markdown]
# Inheritance: Encapsulation refers to the acquisition of objects and methods into new classes from existing classes (parent or base classes). It allows for code reuse and
# establishes a hierarchical relationship between its classes.

# %%
class Vehicle:
    def __init__(self, color):
        self.color = color

class Car(Vehicle):
    def __init__(self, color, make, model):
        super().__init__(color)
        self.make = make
        self.model = model

# %% [markdown]
# Polymorphism: It is the ability of objects which are of different types to be treated as if they were of the same type, which enables writing code that can work with objects
# of different classes.

# %%
class Shape:
    def area(self):
        pass

class Rectangle(Shape):
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width
 * self.height

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
      return 3.14 * self.radius * self.radius

# %% [markdown]
# 3) Class acts as a blueprint for creating objects which defines the attributes (data) and methods (functions) that an object of its class will have.

# %%
class ClassName:
    def __init__(self, attribute1, attribute2):
        self.attribute1 = attribute1
        self.attribute2 = attribute2

    def method1(self):
        # Method body

    def method2(self):
        # Method body

# %% [markdown]
# 4) Variables defined within a class determines its classification based on the scope whether they are instance variables or class variables.
# Instance Variables belong to individual objects where each instance of a class has its own copy of instance variables.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name  # Instance variable
        self.age = age  # Instance variable

Class variables are unique values that have different instances with different values.
class Car:
    wheels = 4  # Class variable

# %% [markdown]
# 5) The __init__ method is a special type of method that is automatically called when an object of the class is created. It is primarily used to
# initialize the attributes of the object.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

# %% [markdown]
# Here, __init__ method takes name and age as parameters and initializes the name and age attributes of the person object.

# %% [markdown]
# 6) 'self' is a special variable that refers to the current instance of a class. It's automatically passed as the first argument to instance methods. 'self' can be used to
# access the instance's attributes and call its methods within the class definition.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print("Hello, my name is", self.name)

# %% [markdown]
# 'cls' is another special variable that refers to the class itself, rather than an instance of the class. It's used in class methods. Class methods can be used to modify
# class attributes, which affects all the instances of the class.

# %%
class MyClass:
    class_attribute = 0

    @classmethod
    def increment_class_attribute(cls):
        cls.class_attribute += 1

# %% [markdown]
# 7) Inheritance is one of the 4 pillars of OOPs concept which acquires the objects and methods into a new class form existing classes. This mechanism promotes reusability of
# code and establishes a hierarchical relationship between classes.

# %%
class Animal:
    def __init__(self, name):
        self.name = name

    def make_sound(self):
        print("Generic animal sound")

class Dog(Animal):
    def make_sound(self):
        print("Woof!")

class Cat(Animal):
    def make_sound(self):
        print("Meow!")

# %% [markdown]
# 8) Method overriding:
# Method overriding occurs when a derived class defines a method which has the same name as the method in the base class. The derived class's method replaces the base class's
# method.

# %%
class Animal:
    def make_sound(self):
        print("Generic animal sound")

class Dog(Animal):
    def make_sound(self):
        print("Woof!")

# %% [markdown]
# Method overloading:
# Method overloading is the ability to define multiple methods with the same name but different parameters.

# %%
def add(x, y):
  return x + y

def add(x, y, z):
    return x + y + z

# %% [markdown]
# 9) Multiple inheritance allows a derived class to inherit attributes and methods from multiple base classes. Its useful for creating classes that combine characteristics from
# different sources.

# %%
class Vehicle:
    def __init__(self, color):
        self.color = color

class Car(Vehicle):
    def __init__(self, color, make, model):
        super().__init__(color)
        self.make = make
        self.model = model

class ElectricVehicle(Vehicle):
    def __init__(self, color, battery_capacity):
        super().__init__(color)
        self.battery_capacity = battery_capacity

class ElectricCar(Car, ElectricVehicle):
    def __init__(self, color, make, model, battery_capacity):
        super().__init__(color, make, model)
        super(Car, self).__init__(color, battery_capacity)

# %% [markdown]
# 10) Abstract classes are classes that cannot be instantiated directly. They serve as blueprints for other classes and often contain abstract methods. Abstract methods are
# methods declared within an abstract class but have no implementation.

# %%
from abc import ABC, abstractmethod

class AbstractClass(ABC):
    @abstractmethod
    def abstract_method(self):
        pass

# %% [markdown]
# 11) Polymorphism is a fundamental concept in object-oriented programming that allows objects of different types to be treated as if they were of the same type. It enables
# you to write generic code that can work with objects of different classes, making your code more flexible and reusable.
#
# Python uses abstract classes to define interfaces that concrete classes must implement. This ensures that objects of different classes can be treated as if they were of
# the same type.

# %%
class Animal:
    def make_sound(self):
        print("Generic animal sound")

class Dog(Animal):
    def make_sound(self):
        print("Woof!")

class Cat(Animal):
    def make_sound(self):
        print("Meow!")

# %% [markdown]
# 12) Encapsulation is a fundamental principle in object-oriented programming that involves bundling data and methods that operate on that data into a single unit.

# %%
class Person:
    def __init__(self, name, age):
        self.__name = name
        self.__age = age

    def get_name(self):
        return self.__name

    def get_age(self):
        return self.__age

    def set_age(self, age):
        if age >= 0:
            self.__age = age
        else:
            print("Age cannot be negative.")
